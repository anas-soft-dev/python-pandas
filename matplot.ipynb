# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the 'c:\laragon\bin\python\python-3.9.10\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# xpoints = np.array([5,7,10])
ypoints = np.array([0,7,3,8,4,5,6])

plt.plot(ypoints,"ok", ms =20, mec="r",ls=":")
plt.show()

# %%
x1=np.array([10,13,15,17])
y1=np.array([5,7,8,11])
x2=np.array([4,16,18,14])
y2=np.array([4,9,12,19])

plt.subplot(2,2,1)

plt.plot(x1,y1,marker="o")
plt.title("Line Graph")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.grid(c="g", lw="1" , ls=":")

plt.subplot(2,2,2)
plt.plot(x2,y2,marker="o")
plt.title("Line Graph")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.grid(c="g", lw="1" , ls=":")
plt.subplot(2,2,3)
plt.plot(x2,y2,marker="o")
plt.title("Line Graph")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.grid(c="g", lw="1" , ls=":")
plt.subplot(2,2,4)
plt.plot(x2,y2,marker="o")
plt.title("Line Graph")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.grid(c="g", lw="1" , ls=":")
plt.show()

# %%
print(plt.colormaps())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'grey', 'gist_grey', 'gist_yerg', 'Grays', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r',
# ...

# %%
x=np.array(range(0,10))
y=np.array([1,23,12,25,19,16,7,10,12,18])
color = np.array([8,6,10,9,4,8,3,7,1,2])
size = np.array([8,6,10,9,4,8,3,7,1,2])*20

plt.scatter(x,y,c=color, s= size,cmap="nipy_spectral")
plt.colorbar()
plt.show()

# %%
x = np.array(["Ali","Ghalib","Noman","Musharaf"])
marks = np.array([80,70,90,85])

plt.bar(x,marks, color=["g","r"])
plt.xlabel("Student")
plt.ylabel("Marks")
plt.show()

# %%
data = np.random.normal(170,10,250)

plt.hist(data,color="r")
plt.show()

# %%
scores = np.array([50,30,10,5,5])
label = ["A","B","C","D","F"]
explod = [0,0.1,0,0,0]

plt.pie(scores,labels=label,explode=explod,startangle=0,autopct="%.2f%%")
plt.legend(title="Grades")
plt.show()
