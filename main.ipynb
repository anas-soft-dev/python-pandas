# %%
import pandas as pd

# %%
list = [1,2,3,4]

series = pd.Series(list)
series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
scores = [75,82,38,49]
indexs = ["english","math","science","urdu"]

series = pd.Series(data=scores, index = indexs)
# series[["math","science"]]
series[["math","science"]]
# Out:
# math       82
# science    38
# dtype: int64

# %%
calories = {
    "day1":380,
    "day2": 420,
    "day3":220
}
sr = pd.Series(calories)
sr
# Out:
# day1    380
# day2    420
# day3    220
# dtype: int64

# %%
data = {
    "calories":[380,420,390],
    "duration":[40,50,45],
    "name":["ali","abid","ghalib"]
}


df = pd.DataFrame(data)
print(df)
df.loc[[0,2]]
# Out:
#    calories  duration    name
# 0       380        40     ali
# 1       420        50    abid
# 2       390        45  ghalib
#    calories  duration    name
# 0       380        40     ali
# 2       390        45  ghalib

# %%
df
# Out:
#    calories  duration    name
# 0       380        40     ali
# 1       420        50    abid
# 2       390        45  ghalib
